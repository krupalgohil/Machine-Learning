# %%
sentence = """
Dr. A.P.J. Abdul Kalam was born on 15 October 1931 in Rameswaram, Tamil Nadu, India. 
He served as the 11th President of India from 2002 to 2007. 
Abdul Kalam studied aerospace engineering at the Madras Institute of Technology. 
He worked with ISRO and DRDO and played a major role in India's missile development program. 
In 1998, he was one of the key figures behind the Pokhran-II nuclear tests conducted in Rajasthan. 
Dr. Kalam received the Bharat Ratna in 1997 for his contribution to science and technology.
"""

# %%
import nltk 
words = nltk.word_tokenize(sentence)

# %%
tag_elements = nltk.pos_tag(words)

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Jay\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Jay\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
nltk.ne_chunk(tag_elements)
# Out:
# Tree('S', [('Dr.', 'NNP'), ('A.P.J', 'NNP'), ('.', '.'), Tree('PERSON', [('Abdul', 'NNP'), ('Kalam', 'NNP')]), ('was', 'VBD'), ('born', 'VBN'), ('on', 'IN'), ('15', 'CD'), ('October', 'NNP'), ('1931', 'CD'), ('in', 'IN'), Tree('GPE', [('Rameswaram', 'NNP')]), (',', ','), Tree('PERSON', [('Tamil', 'NNP'), ('Nadu', 'NNP')]), (',', ','), Tree('GPE', [('India', 'NNP')]), ('.', '.'), ('He', 'PRP'), ('served', 'VBD'), ('as', 'IN'), ('the', 'DT'), ('11th', 'CD'), ('President', 'NNP'), ('of', 'IN'), Tree('GPE', [('India', 'NNP')]), ('from', 'IN'), ('2002', 'CD'), ('to', 'TO'), ('2007', 'CD'), ('.', '.'), Tree('PERSON', [('Abdul', 'NNP'), ('Kalam', 'NNP')]), ('studied', 'VBD'), ('aerospace', 'NN'), ('engineering', 'NN'), ('at', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Madras', 'NNP'), ('Institute', 'NNP')]), ('of', 'IN'), Tree('GPE', [('Technology', 'NNP')]), ('.', '.'), ('He', 'PRP'), ('worked', 'VBD'), ('with', 'IN'), Tree('ORGANIZATION', [('ISRO', 'NNP')]), ('and', 'CC'), Tree('ORGANI
# ...
