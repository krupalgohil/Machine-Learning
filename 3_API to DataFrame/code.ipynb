# %%
import pandas as pd 
import requests

# %%
url = 'https://api.tvmaze.com/search/shows?q=breaking+bad'
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data)

df1 = df.to_dict('records')
df2 = pd.json_normalize(df1)
df2
# Out:
#       score  show.id                                           show.url  \
# 0  1.202395      169      https://www.tvmaze.com/shows/169/breaking-bad
# 1  0.891040    27845  https://www.tvmaze.com/shows/27845/breaking-ba...
# 2  0.545523     1003      https://www.tvmaze.com/shows/1003/talking-bad
# 3  0.477521     6101    https://www.tvmaze.com/shows/6101/breaking-band
# 4  0.452388    37136  https://www.tvmaze.com/shows/37136/breaking-th...
# 5  0.451336    87555  https://www.tvmaze.com/shows/87555/the-bad-guy...
# 6  0.383328    39967  https://www.tvmaze.com/shows/39967/bradley-wal...
# 7  0.310344    16956  https://www.tvmaze.com/shows/16956/baking-mad-...
# 8  0.306475    78429  https://www.tvmaze.com/shows/78429/breaking-da...
#
#                                          show.name    show.type show.language  \
# 0                                     Breaking Bad     Scripted       English
# 1                 Breaking Bad: Original Minisodes     Scripted       English
# 2                                      Talking Bad    Talk Show       English
# 3                                    Breaking Band      Reality       English
# 4                                Breaking the Band  Documentary       English
# 5                        The Bad Guys: Breaking In    Animation       English
# 6                Bradley Walsh & Son: Breaking Dad      Reality       English
# 7                     Baking Mad with Eric Lanlard      Reality       English
# 8  Breaking Dad: Britain's Unlikeliest Drug Dealer  Documentary       English
#
#                 show.genres       show.status  show.runtime  \
# 0  [Drama, Crime, Thriller]             Ended          60.0
# 1           [Comedy, Crime]             Ended           5.0
# 2                        []             Ended          30.0
# 3                   [Music]             Ended          30.0
# 4                        []           Running          60.0
# 5        [Comedy, Children]  To Be Determined           NaN
# 6       [Adventure, Travel]           Running          30.0
# 7                    [Food]             Ended          30.0
# 8                   [Crime]             Ended           NaN
#
#    show.averageRuntime  ...         show._links.previousepisode.href  \
# 0                   60  ...  https://api.tvmaze.com/episodes/2007806
# 1                    5  ...  https://api.tvmaze.com/episodes/1163344
# 2                   30  ...    https://api.tvmaze.com/episodes/98903
# 3                   30  ...   https://api.tvmaze.com/episodes/623356
# 4                   61  ...  https://api.tvmaze.com/episodes/2333163
# 5                   25  ...  https://api.tvmaze.com/episodes/3433109
# 6                   30  ...  https://api.tvmaze.com/episodes/3203305
# 7                   30  ...  https://api.tvmaze.com/episodes/1970695
# 8                   50  ...  https://api.tvmaze.com/episodes/2943275
#
#   show._links.previousepisode.name show.webChannel.id show.webChannel.name  \
# 0  El Camino: A Breaking Bad Movie                NaN                  NaN
# 1                 Fighting for You              142.0              AMC.com
# 2                           Felina                NaN                  NaN
# 3      Mark McGrath & Stick Figure                NaN                  NaN
# 4                         Skid Row                NaN                  NaN
# 5                Crime After Crime                1.0              Netflix
# 6            Thailand (Chiang Mai)                NaN                  NaN
# 7                    Afternoon Tea                NaN                  NaN
# 8                        Episode 2                3.0          Prime Video
#
#   show.webChannel.country.name  show.webChannel.country.code  \
# 0                          NaN                           NaN
# 1                United States                            US
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# 5                          NaN                           NaN
# 6                          NaN                           NaN
# 7                          NaN                           NaN
# 8                          NaN                           NaN
#
#    show.webChannel.country.timezone  show.webChannel.officialSite  \
# 0                               NaN                           NaN
# 1                  America/New_York          https://www.amc.com/
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# 5                               NaN      https://www.netflix.com/
# 6                               NaN                           NaN
# 7                               NaN                           NaN
# 8                               NaN    https://www.primevideo.com
#
#   show.network show.webChannel.country
# 0          NaN                     NaN
# 1          NaN                     NaN
# 2          NaN                     NaN
# 3          NaN                     NaN
# 4          NaN                     NaN
# 5          NaN                     NaN
# 6          NaN                     NaN
# 7          NaN                     NaN
# 8          NaN                     NaN
#
# [9 rows x 43 columns]
